# %%
import pandas as pd
import requests
import datetime

# %%
dfar=pd.read_csv('artistPop_slice2.csv',index_col=[0])

# %%
dfar
# Out:
#                       artistID                     artistName  artistPop
# 200000  5wpATbXhVrHUzbRMM5tuL9               The Golden Horns          0
# 200001  7mbt6xkRJXJegCoXybQv01                 Things To Come          3
# 200002  22ZDRbsmLhEzV7DwGt3oXG                         Ratboy          1
# 200003  5QV2TeBYagwigGwJEt3F2x                   Briget Spins          0
# 200004  5IKjiKoPZEXHmGetueSyZi  Erwin Lehn und sein Orchester          0
# ...                        ...                            ...        ...
# 399995  3t9srsuLgxJ13TQoiaEZNn                          Ramom          0
# 399996  6rJsodEIQYS8tlRy8AKvAR                   Romy So Love         17
# 399997  1YlEh2koUhLzPU7YGtAtgS                        Fee Fee          0
# 399998  65CGpR0JNx6o9pxbqn5PdM                      Zacarocha          0
# 399999  7z7QU6DX8hVP2Xppnewb1e                       Maderita          2
#
# [200000 rows x 3 columns]

# %%
#dfar=df[:1000]

# %%
dfar
# Out:
#                       artistID                     artistName  artistPop
# 200000  5wpATbXhVrHUzbRMM5tuL9               The Golden Horns          0
# 200001  7mbt6xkRJXJegCoXybQv01                 Things To Come          3
# 200002  22ZDRbsmLhEzV7DwGt3oXG                         Ratboy          1
# 200003  5QV2TeBYagwigGwJEt3F2x                   Briget Spins          0
# 200004  5IKjiKoPZEXHmGetueSyZi  Erwin Lehn und sein Orchester          0
# ...                        ...                            ...        ...
# 399995  3t9srsuLgxJ13TQoiaEZNn                          Ramom          0
# 399996  6rJsodEIQYS8tlRy8AKvAR                   Romy So Love         17
# 399997  1YlEh2koUhLzPU7YGtAtgS                        Fee Fee          0
# 399998  65CGpR0JNx6o9pxbqn5PdM                      Zacarocha          0
# 399999  7z7QU6DX8hVP2Xppnewb1e                       Maderita          2
#
# [200000 rows x 3 columns]

# %%
dfid=dfar[["artistID"]]

# %%
dfid
# Out:
#                       artistID
# 200000  5wpATbXhVrHUzbRMM5tuL9
# 200001  7mbt6xkRJXJegCoXybQv01
# 200002  22ZDRbsmLhEzV7DwGt3oXG
# 200003  5QV2TeBYagwigGwJEt3F2x
# 200004  5IKjiKoPZEXHmGetueSyZi
# ...                        ...
# 399995  3t9srsuLgxJ13TQoiaEZNn
# 399996  6rJsodEIQYS8tlRy8AKvAR
# 399997  1YlEh2koUhLzPU7YGtAtgS
# 399998  65CGpR0JNx6o9pxbqn5PdM
# 399999  7z7QU6DX8hVP2Xppnewb1e
#
# [200000 rows x 1 columns]

# %%
client_id = ["" for x in range(21)]
client_secret = ["" for x in range(21)]
refresh_token = ["" for x in range(21)]

# %%
# temp_client_id = client_id[0]
# temp_client_secret = client_secret[0]
# temp_refresh_token = refresh_token[0]

# %%
client_id[0]='bab0752f938d432f84276ffc54de2ec3'
client_secret[0]='ad2cd82fd807439088a0b0d9894f7117'
refresh_token[0]='AQCtBXS6bs9loLFcsbhGVDmuebX9lcJrkqVvnWlzGj9Ro5jegdaQg3L88DWZMk1vjRRm1vAMzU-2hA0cDqUlmIot7f7gi8zGsrWLKh8MaBKsFwFJTRkifD9PFaHVz1d3Y1k'

client_id[1]='413a9a8859a74d9e87d6856205911b23'
client_secret[1]='f558c3501c614ea982770990458f4a3e'
refresh_token[1]='AQAHQ14Zb8vJwLFS8Yu3ImbejaZDdO1CAhy4zw-HGRo2jUbqwxCY91uI9qPo3CBSa5pDblqX-xR9jibjMJ4Xld16gA2yxJSXV3lf_5TEyvJKLi_CYydyO-6B1tSdNASOR48'

client_id[2]='0bd5343f872e483498444c18ae346e50'
client_secret[2]='9db3babae66540b68c2ae74ff65a1a3f'
refresh_token[2]='AQD4_8kfgRBA0cZkPAHuQjemfJ42kVZodzZY4uttzkc-W_jH9LiNsx0XIsXhraJKD8d_BW9JGi5j6fu89eVtYHLiB8U7pDu350h9fV5l8KTxvth-HjzuF60lAKHTe0kTTNI'

client_id[3]='533111abe50944c6a526da9d66d2132b'
client_secret[3]='e619e91b46864493bb577638db761621'
refresh_token[3]='AQCvSKv99FJ0JoVqzOeHTuCiwaQ0fB1iYRCC5c2N5sZ_nt_mhkaBP8sXKb9oXgrCNxt2lN1-tdaC2pQTfFKtaXgqhfWbgQuifRjABvtGWjVDXNAcuMJFgJLfjndTe-l-Qao'

client_id[4]='13e4f7ed5a6c4f2c8ed641cd5265b00c'
client_secret[4]='296ae980e12b4cf0b1524cc16dbae5c8'
refresh_token[4]='AQACdu1vqZauVIXk2d3GY1TuUFx1hyB2ktcwWsq9bgxlRVaIwm1tHugfCkck3UztStbBbRVulIItsaFTCtC0Wl5wtNGPJcInQZjCg8w_SLjeiDhrIVJYoJ8-ijeIRxtbA-k'

client_id[5]='4cafe437550247a399897b45cc6dcb1c'
client_secret[5]='8965f09189a741d6a06d6a3b101b3611'
refresh_token[5]='AQBLqV-ucaLHnHZp5CRU8gau1luiJyDfNwD2Ad5G2AxViHi5uuGte7UYt_QyWBkjuyOhkBDWg1NvNgdk6A_Jk-jTltHQu9j_l3QaqeeEOqeEFTFeRB9E4KyKk6vyf5JnkGY'

client_id[6]='2eb44b30bede4cb7abbb788cb38763f1'
client_secret[6]='16ad9315ed3a47109434f892a761f45d'
refresh_token[6]='AQCmJ2M1B_hMdusmmCapK4Zfg6pWgEqkkFSWODeJa56CE6-Cd7Mchv2oY1KwMKj0SCDCPpjZBI_b_G9zaVF16UzUgjsDjrjExF7tBJGQvYas52AkkPpG5JlXn4w2HZlGF28'

client_id[7]='aec55a4d7ef94cf08f748bd9d7fa57d9'
client_secret[7]='6e8a1c4c6a074811bdf8e8c4b35a1740'
refresh_token[7]='AQBIgrXiCnHMkvp7z7ONOAJCedcW0ZsWpvnEvPGaSgYV8F5R9F1MQ9J0IIgxyN7keyQS4r5fS3J2XmTOPNjSw-LSU-dEM_XJl8rcAV55YwPB11wy9x2uTNwR4qHmEzxH8JA'

# %%
import base64
import requests


def generate_access_token(k):                   
    client_creds = f'{client_id[k]}:{client_secret[k]}'
    client_creds_b64 = base64.b64encode(client_creds.encode())
    client_creds_b64
    
    token_url = 'https://accounts.spotify.com/api/token'
    method = 'POST'

    token_data = {
        'grant_type' : 'refresh_token',
        'refresh_token' : refresh_token[k],
    }

    token_headers = {
        'Authorization' : f'Basic {client_creds_b64.decode()}',
        'Content-Type': 'application/x-www-form-urlencoded',
    }

    token_headers

    req = requests.post(token_url,data=token_data,headers=token_headers)
    token_response_data = req.json()
    req.status_code

    token_response_data = req.json()

#     print(req.status_code)
#     print(token_response_data['access_token'])
#     print('\n\n')
#     print(token_response_data['expires_in'])

    return token_response_data['access_token']

# %%
access_token = generate_access_token(0)
print(access_token)
# Out:
# BQDq-rAqCU_rtzj3QeHycbA-jljow_LtRSMY6Tl6qLYMagHiYVXnjF7xjz-8aGKJfKV_e26ZOs9euP4HQdF2mlHISltMZ_ThDq5RvIrQJfd23lcEbZ0PtY2PC-wPqs6zcRbLN6YSobG9ckrN7IsdmdwO4ZWTsogPspRinVAayiDEccywv7MqLiCAlsfLOKT2pF_P5p3YNPIqt8VzAhkWvSZp0JEYQWiMFutGOUnXbBSMC4A7bi2mbutKgg

# %%
aridlist = dfid.values.tolist()

# %%
aridlist
# Out:
# [['5wpATbXhVrHUzbRMM5tuL9'],
#  ['7mbt6xkRJXJegCoXybQv01'],
#  ['22ZDRbsmLhEzV7DwGt3oXG'],
#  ['5QV2TeBYagwigGwJEt3F2x'],
#  ['5IKjiKoPZEXHmGetueSyZi'],
#  ['1jCcJPQUWSbV7fz8YaRwxd'],
#  ['72FU41te5OsCvKjScvQGw1'],
#  ['5YFb62GJNWbnBNr55Ba5hm'],
#  ['7279qqlhyNfRk5BBwB0GOh'],
#  ['6n0G7LEYkwwDqpQrX8mWrL'],
#  ['5pWytVPHHEKKvm8CSVgLfs'],
#  ['4ljGdf7WSUgs2gc0TVGNGV'],
#  ['6wckH9q9OO4spyVt55s0nq'],
#  ['3dp2HJ48tAImUNfc2ARW9x'],
#  ['5PBgbBiGqg4aLn6uW2nlmY'],
#  ['6G4ugUeWiJAK4pn64sFIzF'],
#  ['1bnzgbvnIEZEu9YRo94PGl'],
#  ['029uS2pMvwk0TsIUTHkyyw'],
#  ['3L3S5mTws7nPBekXPHw1ou'],
#  ['7oWVqQKvOCxJ2FmEq6G4bL'],
#  ['5Ow8WfIDyhBQUtgFJeaLpM'],
#  ['2qASb0xYkbUeJAyTM4nho8'],
#  ['1HaX5KDykAbp3gD0WSMJxK'],
#  ['1yHjFDDYePdq3KcGBEJkRw'],
#  ['3kqaM7acxhrB3Wf3DzDw4R'],
#  ['5JdO8K76wH3sK5J9v3Iyah'],
#  ['67rYd5fPrMqUUXLklYVksw'],
#  ['3iW3xACztLZanYgwCXSYAx'],
#  ['70UIf2MVQfEVX0A6h5V5iN'],
#  ['4ec52yNguqiIkLXqkt7ZV2'],
#  ['5JuGz6YMiir9mFajb8Ba2e'],
#  ['3TaI80UkuKU0ZyEnZuvyS9'],
# ...

# %%
df_artist = pd.DataFrame(columns=['album_name','album_id','release_date','year'])
df_artist
# Out:
# Empty DataFrame
# Columns: [album_name, album_id, release_date, year]
# Index: []

# %%
temp_arr = [" " for x in range(4)]

# %%
""""if j % 10000 == 0:
    access_token = generate_access_token()
    no=j
    name=f'album___{no}.csv'
    df_artist.to_csv(name)
    print(f'Saved to file: {name}')"""
# Out:
# '"if j % 10000 == 0:\n    access_token = generate_access_token()\n    no=j\n    name=f\'album___{no}.csv\'\n    df_artist.to_csv(name)\n    print(f\'Saved to file: {name}\')'

# %%
k=0
access_token = generate_access_token(k)
headers = {
    'Accept': 'application/json',
    'Content-Type': 'application/json',
    'Authorization': 'Bearer '+access_token,
}

params = {
    'include_groups': 'single,album',
    'market': 'US',
    'limit': '20',
    'offset': '0',
}
# print(access_token)
for j in range(197999,200000):
    try:
        print(j)
        artids = aridlist[j][0]
        response = requests.get(f'https://api.spotify.com/v1/artists/{artids}/albums',params=params,headers=headers)
        resp = response.json()  
#         break
        for n in resp["items"]:
            temp_arr[0]=n["name"]
            temp_arr[1]=n["id"]
            temp_arr[2]=n["release_date"]
            tempvar=temp_arr[2]
            tempyr=int(tempvar[:4])
            if tempyr > 2015:
                temp_arr[3]=tempyr
            else:
                continue

            df_artist.loc[len(df_artist.index)] = temp_arr
    except:
        print(f'Error at line: {j}')
        try:
            access_token = generate_access_token(k)
        except:
            k=k+1
            access_token = generate_access_token(k)
            headers = {
               'Accept': 'application/json',
               'Content-Type': 'application/json',
               'Authorization': 'Bearer '+access_token,
            }

            params = {
               'include_groups': 'single,album',
               'market': 'US',
               'limit': '20',
               'offset': '0',
            }
           
   
    if j % 2000 == 0:
        no=j
        name=f'final____album___{no}.csv'
        df_artist.to_csv(name)
        print(f'Saved to file: {name}')  
        k=k+1
        print(f'k:{k}')
        access_token = generate_access_token(k)
        headers = {
           'Accept': 'application/json',
           'Content-Type': 'application/json',
           'Authorization': 'Bearer '+access_token,
        }

        params = {
           'include_groups': 'single,album',
           'market': 'US',
           'limit': '20',
           'offset': '0',
        }
# Out:
# 197999
# 198000
# Saved to file: final____album___198000.csv
# k:1
# 198001
# 198002
# 198003
# 198004
# 198005
# 198006
# 198007
# 198008
# 198009
# 198010
# 198011
# 198012
# 198013
# 198014
# 198015
# 198016
# 198017
# 198018
# 198019
# 198020
# 198021
# 198022
# 198023
# 198024
# 198025
# 198026
# 198027
# 198028
# 198029
# 198030
# 198031
# 198032
# 198033
# 198034
# 198035
# 198036
# 198037
# 198038
# 198039
# 198040
# 198041
# 198042
# 198043
# 198044
# 198045
# 198046
# 198047
# 198048
# 198049
# 198050
# 198051
# 198052
# 198053
# 198054
# 198055
# 198056
# 198057
# 198058
# 198059
# 198060
# 198061
# 198062
# 198063
# 198064
# 198065
# 198066
# 198067
# 198068
# 198069
# 198070
# 198071
# 198072
# 198073
# 198074
# 198075
# 198076
# 198077
# 198078
# 198079
# 198080
# 198081
# 198082
# 198083
# 198084
# 198085
# 198086
# 198087
# 198088
# 198089
# 198090
# 198091
# 198092
# 198093
# 198094
# 198095
# 198096
# 198097
# 198098
# 198099
# 198100
# 198101
# 198102
# 198103
# ...

# %%
print(resp)

# %%
df_artist
# Out:
#                album_name                album_id release_date  year
# 0                  Sultan  2Mmtws99BRT395dsEz8MbP   2022-05-20  2022
# 1       African Fast Food  5MMdCtYPyHLtkxRq8mMUjL   2018-02-23  2018
# 2      Havana-Paris-Dakar  53GjhNIKmPlgG1COi0bIx1   2016-08-26  2016
# 3       Portrait De Maure  1cYWDPH0di1Kaq2NEYeIVC   2022-04-15  2022
# 4          Saba's Journey  6cEOo0WYtM0frU4J2YxqBf   2022-03-04  2022
# ...                   ...                     ...          ...   ...
# 69379     HASSAN & ELIANA  41mAOBslGYQVKZq7gECcKN   2021-02-02  2021
# 69380           Telelumba  2a79qlbPwyfsYmUMZT1dcr   2020-06-19  2020
# 69381    Perfecto (Remix)  4ylgBwvdLOtM0HY57wMRor   2020-03-19  2020
# 69382              Edjing  7ez3EFIG0vogv23nIjC3r0   2019-01-07  2019
# 69383                Baby  5vnEoupihh7mRrYnXqQw38   2018-06-22  2018
#
# [69384 rows x 4 columns]

# %%
df_artist.to_csv("final__albumids_24803.csv")
